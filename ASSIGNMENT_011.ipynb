# %%
# !pip install ultralytics  # for YOLOv8 (includes YOLOv5)
# !pip install opencv-python-headless
# !pip install filterpy
# !pip install numpy
# !pip install matplotlib

# %%
video_path = '/content/drive/MyDrive/Video/Group Therapy for Autism Spectrum Disorder.mp4'

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # Load a pre-trained YOLOv8 model

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
cap = cv2.VideoCapture(video_path)

# %%
# Define the codec and create a VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_video1.mp4', fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    for result in results:
        for box in result.boxes:
            # Extract coordinates and convert to integers
            x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # Convert tensor to list, then to int
            label = result.names[int(box.cls)]

            # Draw bounding box and label on the frame
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Write the frame into the output video file
    out.write(frame)

    # Optionally display the frame
    cv2_imshow(frame)

cap.release()
out.release()  # Ensure to release the VideoWriter object
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import cv2

# Assuming you have a capture object (cap)

# Option 1 (explicit definition)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Option 2 (same dimensions as input video)
# out = cv2.VideoWriter('output_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 20, (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

out = cv2.VideoWriter('output_video1.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 20, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run detection and tracking (as in your previous steps)

    out.write(frame)

cap.release()
out.release()

# %%
import cv2

# ... (your video processing code)

# Save the video in the current working directory (use a different path if needed)
out = cv2.VideoWriter('output_video1.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 20, (width, height))
# ... (write frames to video)
out.release()

# Release capture object
cap.release()
